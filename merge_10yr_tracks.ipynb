# %%
import numpy as np
import glob
import pandas as pd
import matplotlib.pyplot as plt
import iris.plot as iplt
import cartopy.crs as ccrs

# %%
### ALL YEARS COMBINED FOR PLOTS ###
### ---------------------------- ###
####################################

### STARTING WITH THE ORIGINAL (UNFILTERED) TRACKS ###  

import numpy as np
import pandas as pd

year = 1998
file = '/project/cssp_brazil/mcs_tracking_HG/CPM_PD_TRACKS/init_tracks/tracks_{}_INTERP.h5'.format(year)
original_1998 = pd.read_hdf(file, 'table')

# %%
# adding the year to the start of the cell number so that when all the yearly
# dataframes are combined into 1, there are no duplicate cell numbers

for cell in np.unique(original_1998.cell.values):
    if cell < 0:
        continue
    else:
        new_cell = int("1998" + str(cell))
        #print(new_cell)
    original_1998['cell'] = original_1998['cell'].replace(cell, new_cell)

print(np.unique(original_1998.cell.values).shape[0])
# Out:
# 3952

# %%
year = 1999
file = '/project/cssp_brazil/mcs_tracking_HG/CPM_PD_TRACKS/init_tracks/tracks_{}_INTERP.h5'.format(year)
original_1999 = pd.read_hdf(file, 'table')

# %%
# adding the year to the start of the cell number so that when all the yearly
# dataframes are combined into 1, there are no duplicate cell numbers

for cell in np.unique(original_1999.cell.values):
    if cell < 0:
        continue
    else:
        new_cell = int("1999" + str(cell))
        #print(new_cell)
    original_1999['cell'] = original_1999['cell'].replace(cell, new_cell)

print(np.unique(original_1999.cell.values).shape[0])
# Out:
# 4222

# %%
year = 2000
file = '/project/cssp_brazil/mcs_tracking_HG/CPM_PD_TRACKS/init_tracks/tracks_{}_INTERP.h5'.format(year)
original_2000 = pd.read_hdf(file, 'table')

# %%
# adding the year to the start of the cell number so that when all the yearly
# dataframes are combined into 1, there are no duplicate cell numbers

for cell in np.unique(original_2000.cell.values):
    if cell < 0:
        continue
    else:
        new_cell = int("2000" + str(cell))
        #print(new_cell)
    original_2000['cell'] = original_2000['cell'].replace(cell, new_cell)

print(np.unique(original_2000.cell.values).shape[0])
# Out:
# 4082

# %%
year = 2001
file = '/project/cssp_brazil/mcs_tracking_HG/CPM_PD_TRACKS/init_tracks/tracks_{}_INTERP.h5'.format(year)
original_2001 = pd.read_hdf(file, 'table')

# %%
# adding the year to the start of the cell number so that when all the yearly
# dataframes are combined into 1, there are no duplicate cell numbers

for cell in np.unique(original_2001.cell.values):
    if cell < 0:
        continue
    else:
        new_cell = int("2001" + str(cell))
        #print(new_cell)
    original_2001['cell'] = original_2001['cell'].replace(cell, new_cell)

print(np.unique(original_2001.cell.values).shape[0])
# Out:
# 4003

# %%
year = 2002
file = '/project/cssp_brazil/mcs_tracking_HG/CPM_PD_TRACKS/init_tracks/tracks_{}_INTERP.h5'.format(year)
original_2002 = pd.read_hdf(file, 'table')

# %%
# adding the year to the start of the cell number so that when all the yearly
# dataframes are combined into 1, there are no duplicate cell numbers

for cell in np.unique(original_2002.cell.values):
    if cell < 0:
        continue
    else:
        new_cell = int("2002" + str(cell))
        #print(new_cell)
    original_2002['cell'] = original_2002['cell'].replace(cell, new_cell)

print(np.unique(original_2002.cell.values).shape[0])
# Out:
# 3992

# %%
year = 2003
file = '/project/cssp_brazil/mcs_tracking_HG/CPM_PD_TRACKS/init_tracks/tracks_{}_INTERP.h5'.format(year)
original_2003 = pd.read_hdf(file, 'table')

# %%
# adding the year to the start of the cell number so that when all the yearly
# dataframes are combined into 1, there are no duplicate cell numbers

for cell in np.unique(original_2003.cell.values):
    if cell < 0:
        continue
    else:
        new_cell = int("2003" + str(cell))
        #print(new_cell)
    original_2003['cell'] = original_2003['cell'].replace(cell, new_cell)

print(np.unique(original_2003.cell.values).shape[0])
# Out:
# 3977

# %%
year = 2004
file = '/project/cssp_brazil/mcs_tracking_HG/CPM_PD_TRACKS/init_tracks/tracks_{}_INTERP.h5'.format(year)
original_2004 = pd.read_hdf(file, 'table')

# %%
# adding the year to the start of the cell number so that when all the yearly
# dataframes are combined into 1, there are no duplicate cell numbers

for cell in np.unique(original_2004.cell.values):
    if cell < 0:
        continue
    else:
        new_cell = int("2004" + str(cell))
        #print(new_cell)
    original_2004['cell'] = original_2004['cell'].replace(cell, new_cell)

print(np.unique(original_2004.cell.values).shape[0])
# Out:
# 4167

# %%
year = 2005
file = '/project/cssp_brazil/mcs_tracking_HG/CPM_PD_TRACKS/init_tracks/tracks_{}_INTERP.h5'.format(year)
original_2005 = pd.read_hdf(file, 'table')

# %%
# adding the year to the start of the cell number so that when all the yearly
# dataframes are combined into 1, there are no duplicate cell numbers

for cell in np.unique(original_2005.cell.values):
    if cell < 0:
        continue
    else:
        new_cell = int("2005" + str(cell))
        #print(new_cell)
    original_2005['cell'] = original_2005['cell'].replace(cell, new_cell)

print(np.unique(original_2005.cell.values).shape[0])
# Out:
# 3883

# %%
year = 2006
file = '/project/cssp_brazil/mcs_tracking_HG/CPM_PD_TRACKS/init_tracks/tracks_{}_INTERP.h5'.format(year)
original_2006 = pd.read_hdf(file, 'table')

# %%
# adding the year to the start of the cell number so that when all the yearly
# dataframes are combined into 1, there are no duplicate cell numbers

for cell in np.unique(original_2006.cell.values):
    if cell < 0:
        continue
    else:
        new_cell = int("2006" + str(cell))
        #print(new_cell)
    original_2006['cell'] = original_2006['cell'].replace(cell, new_cell)

print(np.unique(original_2006.cell.values).shape[0])
# Out:
# 4034

# %%
year = 2007
file = '/project/cssp_brazil/mcs_tracking_HG/CPM_PD_TRACKS/init_tracks/tracks_{}_INTERP.h5'.format(year)
original_2007 = pd.read_hdf(file, 'table')

# %%
# adding the year to the start of the cell number so that when all the yearly
# dataframes are combined into 1, there are no duplicate cell numbers

for cell in np.unique(original_2007.cell.values):
    if cell < 0:
        continue
    else:
        new_cell = int("2007" + str(cell))
        #print(new_cell)
    original_2007['cell'] = original_2007['cell'].replace(cell, new_cell)

print(np.unique(original_2007.cell.values).shape[0])
# Out:
# 3987

# %%
all_years_original = pd.DataFrame()

all_years_original = pd.concat([all_years_original, original_1998, original_1999, original_2000, original_2001, original_2002, original_2003, original_2004, original_2005, original_2006, original_2007])

# %%
all_years_original
# Out:
#        frame  idx      hdim_1      hdim_2    num  threshold_value  feature  \
# 0          0    4   21.380386  289.872793    887              240        1
# 1          0    9   41.648762   91.618257   1061              240        2
# 2          0   15   81.293591  178.298117    453              240        3
# 3          0   19  182.474270  409.596592  11434              240        4
# 4          0   21  122.600289  211.430921    846              240        5
# ...      ...  ...         ...         ...    ...              ...      ...
# 87548   8615  114  381.026823  177.106745   1502              240    87549
# 87549   8615  146  380.479104  370.942339    556              240    87550
# 87550   8615  170  421.483733  515.509992   1181              240    87551
# 87551   8615  184  427.224173  162.441710   1149              240    87552
# 87552   8615  215  453.824262   80.711020    872              240    87553
#
#                       time              timestr   latitude  longitude  \
# 0      1998-01-01 00:30:00  1998-01-01 00:30:00 -37.811960 -55.962721
# 1      1998-01-01 00:30:00  1998-01-01 00:30:00 -35.785123 -75.788174
# 2      1998-01-01 00:30:00  1998-01-01 00:30:00 -31.820641 -67.120190
# 3      1998-01-01 00:30:00  1998-01-01 00:30:00 -21.702573 -43.990341
# 4      1998-01-01 00:30:00  1998-01-01 00:30:00 -27.689971 -63.806907
# ...                    ...                  ...        ...        ...
# 87548  2007-12-29 23:30:00  2007-12-29 23:30:00  -1.847318 -67.239326
# 87549  2007-12-29 23:30:00  2007-12-29 23:30:00  -1.902090 -47.855765
# 87550  2007-12-29 23:30:00  2007-12-29 23:30:00   2.198373 -33.399000
# 87551  2007-12-29 23:30:00  2007-12-29 23:30:00   2.772417 -68.705830
# 87552  2007-12-29 23:30:00  2007-12-29 23:30:00   5.432426 -76.878896
#
#             cell       time_cell
# 0             -1             NaT
# 1          19982 0 days 00:00:00
# 2          19983 0 days 00:00:00
# 3             -1             NaT
# 4          19985 0 days 00:00:00
# ...          ...             ...
# 87548         -1             NaT
# 87549         -1             NaT
# 87550  200718129 1 days 10:00:00
# 87551         -1             NaT
# 87552  200718188 0 days 06:00:00
#
# [892002 rows x 13 columns]

# %%
print(np.unique(all_years_original.cell.values).shape[0])
# Out:
# 40290

# %%
### NOW THE FINAL (FILTERED) TRACKS ###

year = 1998
file = '/project/cssp_brazil/mcs_tracking_HG/CPM_HINDCAST_TRACKS/final_tracks_CPM_INTERP/merged/{}/CCPF_{}.hdf'.format(year, year)
CCPF_1998 = pd.read_hdf(file, 'table')

# %%
# adding the year to the start of the cell number so that when all the yearly
# dataframes are combined into 1, there are no duplicate cell numbers

for cell in np.unique(CCPF_1998.cell.values):
    if cell < 0:
        continue
    else:
        new_cell = int("1998" + str(cell))
        #print(new_cell)
    CCPF_1998['cell'] = CCPF_1998['cell'].replace(cell, new_cell)

print(np.unique(CCPF_1998.cell.values).shape[0])
# Out:
# 2639

# %%
year = 1999
file = '/project/cssp_brazil/mcs_tracking_HG/CPM_HINDCAST_TRACKS/final_tracks_CPM_INTERP/merged/{}/CCPF_{}.hdf'.format(year, year)
CCPF_1999 = pd.read_hdf(file, 'table')

# %%
# adding the year to the start of the cell number so that when all the yearly
# dataframes are combined into 1, there are no duplicate cell numbers

for cell in np.unique(CCPF_1999.cell.values):
    if cell < 0:
        continue
    else:
        new_cell = int("1999" + str(cell))
        #print(new_cell)
    CCPF_1999['cell'] = CCPF_1999['cell'].replace(cell, new_cell)

print(np.unique(CCPF_1999.cell.values).shape[0])
# Out:
# 2885

# %%
year = 2000
file = '/project/cssp_brazil/mcs_tracking_HG/CPM_HINDCAST_TRACKS/final_tracks_CPM_INTERP/merged/{}/CCPF_{}.hdf'.format(year, year)
CCPF_2000 = pd.read_hdf(file, 'table')

# %%
# adding the year to the start of the cell number so that when all the yearly
# dataframes are combined into 1, there are no duplicate cell numbers

for cell in np.unique(CCPF_2000.cell.values):
    if cell < 0:
        continue
    else:
        new_cell = int("2000" + str(cell))
        #print(new_cell)
    CCPF_2000['cell'] = CCPF_2000['cell'].replace(cell, new_cell)

print(np.unique(CCPF_2000.cell.values).shape[0])
# Out:
# 2828

# %%
year = 2001
file = '/project/cssp_brazil/mcs_tracking_HG/CPM_HINDCAST_TRACKS/final_tracks_CPM_INTERP/merged/{}/CCPF_{}.hdf'.format(year, year)
CCPF_2001 = pd.read_hdf(file, 'table')

# adding the year to the start of the cell number so that when all the yearly
# dataframes are combined into 1, there are no duplicate cell numbers

for cell in np.unique(CCPF_2001.cell.values):
    if cell < 0:
        continue
    else:
        new_cell = int("2001" + str(cell))
        #print(new_cell)
    CCPF_2001['cell'] = CCPF_2001['cell'].replace(cell, new_cell)

print(np.unique(CCPF_2001.cell.values).shape[0])
# Out:
# 2667

# %%
year = 2002
file = '/project/cssp_brazil/mcs_tracking_HG/CPM_HINDCAST_TRACKS/final_tracks_CPM_INTERP/merged/{}/CCPF_{}.hdf'.format(year, year)
CCPF_2002 = pd.read_hdf(file, 'table')

# adding the year to the start of the cell number so that when all the yearly
# dataframes are combined into 1, there are no duplicate cell numbers

for cell in np.unique(CCPF_2002.cell.values):
    if cell < 0:
        continue
    else:
        new_cell = int("2002" + str(cell))
        #print(new_cell)
    CCPF_2002['cell'] = CCPF_2002['cell'].replace(cell, new_cell)

print(np.unique(CCPF_2002.cell.values).shape[0])
# Out:
# 2690

# %%
year = 2003
file = '/project/cssp_brazil/mcs_tracking_HG/CPM_HINDCAST_TRACKS/final_tracks_CPM_INTERP/merged/{}/CCPF_{}.hdf'.format(year, year)
CCPF_2003 = pd.read_hdf(file, 'table')

# adding the year to the start of the cell number so that when all the yearly
# dataframes are combined into 1, there are no duplicate cell numbers

for cell in np.unique(CCPF_2003.cell.values):
    if cell < 0:
        continue
    else:
        new_cell = int("2003" + str(cell))
        #print(new_cell)
    CCPF_2003['cell'] = CCPF_2003['cell'].replace(cell, new_cell)

print(np.unique(CCPF_2003.cell.values).shape[0])
# Out:
# 2733

# %%
year = 2004
file = '/project/cssp_brazil/mcs_tracking_HG/CPM_HINDCAST_TRACKS/final_tracks_CPM_INTERP/merged/{}/CCPF_{}.hdf'.format(year, year)
CCPF_2004 = pd.read_hdf(file, 'table')

# adding the year to the start of the cell number so that when all the yearly
# dataframes are combined into 1, there are no duplicate cell numbers

for cell in np.unique(CCPF_2004.cell.values):
    if cell < 0:
        continue
    else:
        new_cell = int("2004" + str(cell))
        #print(new_cell)
    CCPF_2004['cell'] = CCPF_2004['cell'].replace(cell, new_cell)

print(np.unique(CCPF_2004.cell.values).shape[0])
# Out:
# 2776

# %%
year = 2005
file = '/project/cssp_brazil/mcs_tracking_HG/CPM_HINDCAST_TRACKS/final_tracks_CPM_INTERP/merged/{}/CCPF_{}.hdf'.format(year, year)
CCPF_2005 = pd.read_hdf(file, 'table')

# adding the year to the start of the cell number so that when all the yearly
# dataframes are combined into 1, there are no duplicate cell numbers

for cell in np.unique(CCPF_2005.cell.values):
    if cell < 0:
        continue
    else:
        new_cell = int("2005" + str(cell))
        #print(new_cell)
    CCPF_2005['cell'] = CCPF_2005['cell'].replace(cell, new_cell)

print(np.unique(CCPF_2005.cell.values).shape[0])
# Out:
# 2613

# %%
year = 2006
file = '/project/cssp_brazil/mcs_tracking_HG/CPM_HINDCAST_TRACKS/final_tracks_CPM_INTERP/merged/{}/CCPF_{}.hdf'.format(year, year)
CCPF_2006 = pd.read_hdf(file, 'table')

# adding the year to the start of the cell number so that when all the yearly
# dataframes are combined into 1, there are no duplicate cell numbers

for cell in np.unique(CCPF_2006.cell.values):
    if cell < 0:
        continue
    else:
        new_cell = int("2006" + str(cell))
        #print(new_cell)
    CCPF_2006['cell'] = CCPF_2006['cell'].replace(cell, new_cell)

print(np.unique(CCPF_2006.cell.values).shape[0])
# Out:
# 2725

# %%
year = 2007
file = '/project/cssp_brazil/mcs_tracking_HG/CPM_HINDCAST_TRACKS/final_tracks_CPM_INTERP/merged/{}/CCPF_{}.hdf'.format(year, year)
CCPF_2007 = pd.read_hdf(file, 'table')

# adding the year to the start of the cell number so that when all the yearly
# dataframes are combined into 1, there are no duplicate cell numbers

for cell in np.unique(CCPF_2007.cell.values):
    if cell < 0:
        continue
    else:
        new_cell = int("2007" + str(cell))
        #print(new_cell)
    CCPF_2007['cell'] = CCPF_2007['cell'].replace(cell, new_cell)

print(np.unique(CCPF_2007.cell.values).shape[0])
# Out:
# 2776

# %%
all_years_CCPF = pd.DataFrame()

all_years_CCPF = pd.concat([all_years_CCPF, CCPF_1998, CCPF_1999, CCPF_2000, CCPF_2001, CCPF_2002, CCPF_2003, CCPF_2004, CCPF_2005, CCPF_2006, CCPF_2007])

# %%
all_years_CCPF
# Out:
#        frame  idx      hdim_1      hdim_2   num  threshold_value  feature  \
# 30226   2966  187  504.227820  139.781958   441              240    30227
# 30237   2967  204  506.010937  140.662775   491              240    30238
# 30248   2968  237  509.312528  138.913403   846              240    30249
# 30260   2969  269  510.574439  141.108685   862              240    30261
# 30276   2970  294  509.504562  148.511240  1081              240    30277
# ...      ...  ...         ...         ...   ...              ...      ...
# 20460   1923   11  212.122125  477.667032   640              240    20461
# 20477   1924   13  212.825170  478.221074   689              240    20478
# 20490   1925   15  213.903893  478.756194   694              240    20491
# 20505   1926   14  215.151768  478.119131   568              240    20506
# 20522   1927    8  215.188848  478.081889   477              240    20523
#
#                       time              timestr   latitude  ...  w_5_down  \
# 30226  1998-05-04 14:30:00  1998-05-04 14:30:00  10.472782  ...       NaN
# 30237  1998-05-04 15:30:00  1998-05-04 15:30:00  10.651093  ...       0.0
# 30248  1998-05-04 16:30:00  1998-05-04 16:30:00  10.981253  ...       NaN
# 30260  1998-05-04 17:30:00  1998-05-04 17:30:00  11.107444  ...       NaN
# 30276  1998-05-04 18:30:00  1998-05-04 18:30:00  11.000456  ...       0.0
# ...                    ...                  ...        ...  ...       ...
# 20460  2007-03-22 03:30:00  2007-03-22 03:30:00 -18.737787  ...       0.0
# 20477  2007-03-22 04:30:00  2007-03-22 04:30:00 -18.667483  ...       NaN
# 20490  2007-03-22 05:30:00  2007-03-22 05:30:00 -18.559610  ...       NaN
# 20505  2007-03-22 06:30:00  2007-03-22 06:30:00 -18.434824  ...       0.0
# 20522  2007-03-22 07:30:00  2007-03-22 07:30:00 -18.431116  ...       NaN
#
#        max_precip_lat max_precip_lon min_tb_lat  min_tb_lon  max_w_up_lat  \
# 30226            9.65         -75.75       9.85  -75.849998             0
# 30237            9.55         -75.75      10.05  -75.849998          9.65
# 30248            9.75     -75.849998      10.05  -75.550003             0
# 30260            9.55     -75.949997      10.15  -76.449997             0
# 30276            9.95         -76.25      10.45  -75.650002          9.65
# ...               ...            ...        ...         ...           ...
# 20460          -18.35     -41.950001     -18.35  -41.950001        -18.35
# 20477          -18.35     -41.950001     -18.35  -41.950001             0
# 20490          -18.15     -42.049999     -18.25  -42.049999             0
# 20505          -18.15     -41.950001     -18.15  -41.950001        -18.15
# 20522          -18.15     -41.950001     -18.15  -42.049999             0
#
#        max_w_up_lon  max_w_down_lat  max_w_down_lon  colocated_pixels
# 30226             0               0               0                47
# 30237        -75.75            9.85          -75.75                36
# 30248             0               0               0                33
# 30260             0               0               0                26
# 30276    -75.949997           10.15      -75.349998                 5
# ...             ...             ...             ...               ...
# 20460    -41.849998      -18.549999      -42.049999               156
# 20477             0               0               0               130
# 20490             0               0               0                93
# 20505    -41.950001          -18.25          -41.75                67
# 20522             0               0               0                31
#
# [379463 rows x 52 columns]

# %%
all_years_CCPF.sort_values(by=['timestr'])
# Out:
#        frame  idx      hdim_1      hdim_2   num  threshold_value  feature  \
# 7          0  114  399.883902  579.791578  1518              240        8
# 6          0   92  370.015216  215.883104  4986              240        7
# 10         1    5  183.803925  375.924627  2712              240       11
# 17         1  101  400.157501  578.898111  1489              240       18
# 15         1   82  364.461865  208.281038  5792              240       16
# ...      ...  ...         ...         ...   ...              ...      ...
# 91092   8758   35  262.435465  211.524927  1399              240    91093
# 91100   8758  143  381.504918  520.362722   946              240    91101
# 91107   8759   62  272.571686  203.763047   786              240    91108
# 91112   8759  120  328.515315  443.253353   613              240    91113
# 91113   8759  133  382.224095  525.873568  1298              240    91114
#
#                       time              timestr   latitude  ...  w_5_down  \
# 7      1998-01-01 00:30:00  1998-01-01 00:30:00   0.038390  ...       0.0
# 6      1998-01-01 00:30:00  1998-01-01 00:30:00  -2.948478  ...       0.0
# 10     1998-01-01 01:30:00  1998-01-01 01:30:00 -21.569607  ...       NaN
# 17     1998-01-01 01:30:00  1998-01-01 01:30:00   0.065750  ...       NaN
# 15     1998-01-01 01:30:00  1998-01-01 01:30:00  -3.503814  ...       NaN
# ...                    ...                  ...        ...  ...       ...
# 91092  2007-12-31 22:30:00  2007-12-31 22:30:00 -13.706453  ...       NaN
# 91100  2007-12-31 22:30:00  2007-12-31 22:30:00  -1.799508  ...       NaN
# 91107  2007-12-31 23:30:00  2007-12-31 23:30:00 -12.692831  ...       NaN
# 91112  2007-12-31 23:30:00  2007-12-31 23:30:00  -7.098469  ...       NaN
# 91113  2007-12-31 23:30:00  2007-12-31 23:30:00  -1.727590  ...       NaN
#
#        max_precip_lat max_precip_lon min_tb_lat  min_tb_lon  max_w_up_lat  \
# 7                0.35     -34.849998       0.35  -34.549999         -4.05
# 6               -0.75         -72.75      -2.35  -69.949997         -8.25
# 10             -19.35     -51.650002 -20.450001  -53.549999             0
# 17               1.95         -31.35       0.35      -34.25           0.0
# 15              -3.85     -70.349998      -4.15  -70.349998           0.0
# ...               ...            ...        ...         ...           ...
# 91092          -12.15     -69.349998     -12.55  -70.050003             0
# 91100           -1.45     -38.849998      -1.55  -38.650002             0
# 91107          -11.85         -69.75     -12.35  -69.650002             0
# 91112           -6.95     -47.650002      -6.85  -47.450001             0
# 91113           -0.95     -38.849998      -1.05  -38.849998             0
#
#        max_w_up_lon  max_w_down_lat  max_w_down_lon  colocated_pixels
# 7        -34.950001           -4.05      -34.950001                20
# 6            -73.25           -8.25          -73.25               758
# 10                0               0               0               287
# 17              0.0             0.0             0.0                16
# 15              0.0             0.0             0.0               799
# ...             ...             ...             ...               ...
# 91092             0               0               0                93
# 91100             0               0               0                33
# 91107             0               0               0                15
# 91112             0               0               0                 2
# 91113             0               0               0                58
#
# [379463 rows x 52 columns]

# %%
print(np.unique(all_years_CCPF.cell.values).shape[0])
# Out:
# 27332

# %%
all_years_CCPF.to_hdf('/project/cssp_brazil/mcs_tracking_HG/CPM_HINDCAST_TRACKS/final_tracks_CPM_INTERP/merged/all_years_combined_CCPF/all_years_CCPF.hdf', 'table')

#all_years_original.to_hdf('/project/cssp_brazil/mcs_tracking_HG/CPM_PD_TRACKS/init_tracks/all_years_combined/all_years_initial_cpm_pd.hdf', 'table')
# Out:
# /var/tmp/ipykernel_20388/3582181033.py:1: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed-integer,key->block3_values] [items->Index(['time', 'timestr', 'max_precip_lat', 'max_precip_lon', 'min_tb_lat',
#        'min_tb_lon', 'max_w_up_lat', 'max_w_up_lon', 'max_w_down_lat',
#        'max_w_down_lon'],
#       dtype='object')]
#
#   all_years_CCPF.to_hdf('/project/cssp_brazil/mcs_tracking_HG/CPM_HINDCAST_TRACKS/final_tracks_CPM_INTERP/merged/all_years_combined_CCPF/all_years_CCPF.hdf', 'table')

# %%
all_years_original = pd.read_hdf('/project/cssp_brazil/mcs_tracking_HG/CPM_HINDCAST_TRACKS/init_tracks_cpm/all_years_combined/all_years_initial_cpm_hindcast.hdf', 'table')

# %%
all_years_original.time.dtype
# Out:
# dtype('O')

# %%
## stats for pre and post filtering ##
# ---------------------------------------
print('Stats for all years combined:')
print(' ')

print(np.unique(all_years_original.cell.values).shape[0], "cells in the original non-filtered dataset")

print(np.unique(all_years_CCPF.cell.values).shape[0], "cells that met both criteria post-filtering")

print("Total of", (np.unique(all_years_original.cell.values).shape[0])-(np.unique(all_years_CCPF.cell.values).shape[0]), "cells removed post-filtering")

print(((((np.unique(all_years_original.cell.values).shape[0])-(np.unique(all_years_CCPF.cell.values).shape[0]))/(np.unique(all_years_original.cell.values).shape[0]))*100), "% decrease")
# Out:
# Stats for all years combined:
#
# 40290 cells in the original non-filtered dataset
# 27642 cells that met both criteria post-filtering
# Total of 12648 cells removed post-filtering
# 31.39240506329114 % decrease

# %%
dataframes= [all_years_CCPF, all_years_original]

for df in dataframes:
    df.timestr = df.timestr.astype(str)
    df['datetime'] = pd.to_datetime(df.timestr.str.split(',\s*').str[0]) 
    set(df['datetime'])

# %%
# plot of initiation and dissipation times
# ========================================
import functions

#filtered (CC=210K)
init_hours_filtered = functions.get_mcs_init(all_years_CCPF)
init_hours_filtered = np.array(init_hours_filtered)
init_hours_filtered, bins = np.histogram(init_hours_filtered, bins = np.arange(0,25))

diss_hours_filtered = functions.get_mcs_diss(all_years_CCPF)
diss_hours_filtered = np.array(diss_hours_filtered)
diss_hours_filtered, bins = np.histogram(diss_hours_filtered, bins = np.arange(0,25))

init_filtered = init_hours_filtered/np.nansum(init_hours_filtered) * 100
diss_filtered = diss_hours_filtered/np.nansum(diss_hours_filtered) * 100

max_hours_rain_filtered = functions.get_mcs_max_precip(all_years_CCPF)

max_hours_tb_filtered = functions.get_mcs_min_tb(all_years_CCPF)


#unfiltered
init_hours_unfiltered = functions.get_mcs_init(all_years_original)
init_hours_unfiltered = np.array(init_hours_unfiltered)
init_hours_unfiltered, bins = np.histogram(init_hours_unfiltered, bins = np.arange(0,25))

diss_hours_unfiltered = functions.get_mcs_diss(all_years_original)
diss_hours_unfiltered = np.array(diss_hours_unfiltered)
diss_hours_unfiltered, bins = np.histogram(diss_hours_unfiltered, bins = np.arange(0,25))

init_unfiltered = init_hours_unfiltered/np.nansum(init_hours_unfiltered) * 100
diss_unfiltered = diss_hours_unfiltered/np.nansum(diss_hours_unfiltered) * 100

# %%
#plot of initiation time of MCSs 
import seaborn as sns 
sns.set()

plt.figure(figsize=(26,20))
f= 30
lf= 30
l=32

ax1 = plt.subplot(2, 1, 1) 
ax1.set_title('a) Original (unfiltered) ', loc='left', fontsize= 35 )
ax1.plot(np.arange(0,24), init_unfiltered, label = 'initiation ', color= 'darkblue', linewidth = 3)
ax1.plot(np.arange(0,24), diss_unfiltered, label = 'dissipation ', color= 'darkblue', linewidth = 3, linestyle = 'dotted')
#ax1.plot(np.arange(0,24), max_hours_rain_unfiltered, label = 'rain_maxima ', color= 'darkblue', linewidth = 3, linestyle = '-')
#ax1.plot(np.arange(0,24), max_hours_tb_unfiltered, label = 'tb_minima ', color= 'darkblue', linewidth = 3, linestyle = '-,')
ax1.legend(fontsize=lf)

a= np.arange(21,24,2)
b= np.arange(1,20,2)
localtime= np.append(a, b)

labels=localtime.astype(str)
ax1.set_yticks(np.arange(2,10,2))
ax1.set_xticks(np.arange(0,23)[::2])
ax1.set_yticklabels(ax1.get_yticks(),fontsize=f)
ax1.set_xticklabels(labels,fontsize= f)
ax1.set_xlim(-0.5,22.5)
ax1.set_xlabel('Local time (UTC-3)', fontsize= l)
ax1.set_ylabel('Frequency [%]', fontsize= l)


labels=localtime.astype(str)
ax2 = plt.subplot(2, 1, 2) 
ax2.set_title('b) Filtered for cold core and precip', loc='left', fontsize= 35 )
ax2.plot(np.arange(0,24), init_filtered, label = 'initiation ', color= 'crimson', linewidth = 3)
ax2.plot(np.arange(0,24), diss_filtered, label = 'dissipation ', color= 'crimson', linewidth = 3, linestyle = 'dotted')
#ax2.plot(np.arange(0,24), max_hours_rain_filtered, label = 'rain_maxima ', color= 'crimson', linewidth = 3, linestyle = '-.',alpha=0.5)
#ax2.plot(np.arange(0,24), max_hours_tb_filtered, label = 'tb_minima ', color= 'crimson', linewidth = 3, linestyle = '--',alpha=0.5)

ax2.legend(fontsize=lf)
ax2.set_yticks(np.arange(2,10,2))
ax2.set_xticks(np.arange(0,23)[::2])
ax2.set_xticklabels(labels,fontsize= f)
ax2.set_xlim(-0.5,22.5)
ax2.set_yticklabels(ax2.get_yticks(),fontsize=f)
ax2.set_xlabel('Local time (UTC-3)', fontsize= l)
ax2.set_ylabel('Frequency [%]', fontsize= l)

plt.tight_layout()

# %%
# MCS area plots
# ==============
area_unfiltered=functions.get_area(all_years_original)
area_filtered=functions.get_area(all_years_CCPF)
# Out:
# array of MCS areas generated.
# array of MCS areas generated.

# %%
u_area_histo, bins = np.histogram(area_unfiltered, bins= np.linspace(60000,420000,10))
f_area_histo, bins = np.histogram(area_filtered, bins= np.linspace(60000,420000,10))

# %%
#plot of initiation time of MCSs 
import seaborn as sns 
sns.set(font_scale=1.5)

plt.figure(figsize=(16,10))
t = 40
f= 30
n=25
lf= 35

plt.title('MCS area', loc='left', fontsize= t )
plt.bar(bins[:-1],u_area_histo,width=35000*0.7,color= 'teal', label='original')
plt.xlabel('MCS area (km$^{2}$)', fontsize= f)
plt.xticks(bins.astype(int)[:-1], fontsize=n)
#plt.xticks([60000,100000,140000,180000,220000,260000,300000,340000,380000,420000,460000], fontsize=n)
#plt.yticks(np.arange(0,140)[::10],fontsize=n)
#plt.yticks([0,20,40,60,80,100],fontsize=n)
plt.yticks(fontsize=n)
plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))
#ax1.xaxis.get_offset_text().set_fontsize(25)
plt.ylabel('MCS tracks',fontsize=f)

plt.bar(bins[:-1],f_area_histo, width=35000*0.05,color= 'orange',label='filtered')

plt.legend(loc='best',fontsize=f)
#fig.tight_layout()

# %%
u_area_hist = u_area_histo/np.nansum(u_area_histo) * 100
f_area_hist = f_area_histo/np.nansum(f_area_histo) * 100


#plot of initiation time of MCSs 
import seaborn as sns 
sns.set(font_scale=1.5)

plt.figure(figsize=(16,10))
t = 40
f= 30
n=25
lf= 35

plt.title('MCS area', loc='left', fontsize= t )
plt.bar(bins[:-1],u_area_hist,width=35000*0.7,color= 'teal', label='original')
plt.xlabel('MCS area (km$^{2}$)', fontsize= f)
plt.xticks(bins.astype(int)[:-1], fontsize=n)
#plt.xticks([60000,100000,140000,180000,220000,260000,300000,340000,380000,420000,460000], fontsize=n)
plt.yticks(np.arange(0,140)[::10],fontsize=n)
#plt.yticks([0,20,40,60,80,100],fontsize=n)
plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))
#ax1.xaxis.get_offset_text().set_fontsize(25)
plt.ylabel('Frequency [%]',fontsize=f)

plt.bar(bins[:-1],f_area_hist, width=35000*0.05,color= 'orange',label='filtered')

plt.legend(loc='best',fontsize=f)
#fig.tight_layout()

# %%
# plots for velocity
# ==================

# Need to remane the columns to latitude and longitude (and -360 from the longitude) for velocity function and plotting to work 
all_years_original.rename(columns={'projection_x_coordinate': 'longitude', 'projection_y_coordinate': 'latitude'}, inplace=True)
#all_years_CCPF.rename(columns={'projection_x_coordinate': 'longitude', 'projection_y_coordinate': 'latitude'}, inplace=True)

all_years_original.longitude = all_years_original.longitude - 360
#all_years_CCPF.longitude = all_years_CCPF.longitude - 360

# %%
all_years_CCPF.cell
# Out:
# 15651     19983829
# 15660     19983829
# 15670     19983829
# 15679     19983829
# 15691     19983829
#            ...
# 66806    200715121
# 66814    200715121
# 66825    200715121
# 66836    200715121
# 66848    200715121
# Name: cell, Length: 423258, dtype: int64

# %%
subset_CCPF = all_years_CCPF[all_years_CCPF.cell == 19983829]
subset_CCPF
# Out:
#        frame  idx      hdim_1      hdim_2    num  threshold_value  feature  \
# 15651   1380   93  771.369817  211.990152   2412              240    15652
# 15660   1381   90  775.818514  218.611922   4572              240    15661
# 15670   1382   96  773.524616  217.623450   5171              240    15671
# 15679   1383   91  767.841475  228.466812   7251              240    15680
# 15691   1384  160  765.556522  225.455483   8047              240    15692
# 15700   1385  154  761.563264  217.941182   7316              240    15701
# 15709   1386  166  756.929558  218.999963   8347              240    15710
# 15720   1387  142  769.743858  205.119160  12230              240    15721
# 15730   1388  123  762.271046  214.427321  16374              240    15731
# 15743   1389  107  764.427372  236.105463  24395              240    15744
#
#                       time              timestr  projection_y_coordinate  ...  \
# 15651  1998-02-27 12:30:00  1998-02-27 12:30:00                -8.799573  ...
# 15660  1998-02-27 13:30:00  1998-02-27 13:30:00                -8.619401  ...
# 15670  1998-02-27 14:30:00  1998-02-27 14:30:00                -8.712304  ...
# 15679  1998-02-27 15:30:00  1998-02-27 15:30:00                -8.942471  ...
# 15691  1998-02-27 16:30:00  1998-02-27 16:30:00                -9.035011  ...
# 15700  1998-02-27 17:30:00  1998-02-27 17:30:00                -9.196739  ...
# 15709  1998-02-27 18:30:00  1998-02-27 18:30:00                -9.384403  ...
# 15720  1998-02-27 19:30:00  1998-02-27 19:30:00                -8.865424  ...
# 15730  1998-02-27 20:30:00  1998-02-27 20:30:00                -9.168073  ...
# 15743  1998-02-27 21:30:00  1998-02-27 21:30:00                -9.080742  ...
#
#        max_precip_lat  max_precip_lon min_tb_lat  min_tb_lon  max_w_up_lat  \
# 15651           -8.05      -76.349998      -8.05  -76.449997         -8.05
# 15660           -8.15          -75.75      -7.75  -75.349998             0
# 15670           -8.35          -75.75      -8.25      -75.75             0
# 15679           -8.75          -75.75      -8.45  -75.849998         -8.65
# 15691          -10.75      -74.449997      -9.55  -74.949997             0
# 15700          -10.35      -74.449997      -9.55  -75.050003             0
# 15709           -9.75      -75.150002      -9.55  -75.050003         -9.55
# 15720           -7.35          -78.75      -7.35  -78.650002             0
# 15730           -7.85      -73.449997      -6.75  -75.550003             0
# 15743           -7.95      -73.349998      -7.95  -73.349998        -11.85
#
#        max_w_up_lon  max_w_down_lat  max_w_down_lon  colocated_pixels  hour
# 15651    -76.449997           -9.45      -75.849998                77    12
# 15660             0               0               0               106    13
# 15670             0               0               0                98    14
# 15679        -75.75          -10.25          -75.75               146    15
# 15691             0               0               0               161    16
# 15700             0               0               0               211    17
# 15709    -75.150002           -8.25      -75.550003               223    18
# 15720             0               0               0               190    19
# 15730             0               0               0               243    20
# 15743    -71.349998          -10.75      -70.449997               349    21
#
# [10 rows x 53 columns]

# %%
subset_original = all_years_original[all_years_original.cell == 19981]
subset_original
# Out:
#      frame  idx      hdim_1       hdim_2    num  threshold_value  feature  \
# 0        0    2  106.094677   542.929600  31239              240        1
# 11       1    3  107.685873   552.813250  31490              240       12
# 22       2    2  108.269844   561.840211  31852              240       23
# 32       3    2  108.115039   575.691689  32671              240       33
# 42       4    1  108.144396   590.299973  33018              240       43
# 53       5    1  109.781001   604.874107  34177              240       54
# 62       6    1  109.973849   621.199936  34388              240       63
# 71       7    1  110.911888   640.378594  34201              240       72
# 80       8    1  108.452546   664.165920  33895              240       81
# 87       9    1  104.679612   688.292544  32921              240       88
# 93      10    2  101.429370   711.389212  30249              240       94
# 99      11    1  100.577113   731.653392  25012              240      100
# 107     12    1  105.485671   749.815944  22807              240      108
# 114     13    1  115.157957   766.715927  22144              240      115
# 119     14    2  137.499571   773.166769  19639              240      120
# 126     15    1  151.592199   770.563430  19338              240      127
# 135     16    3  159.496673   792.922252  17038              240      136
# 146     17    4  166.555494   805.007704  15660              240      147
# 161     18    3  175.399708   801.629851  14934              240      162
# 176     19    5  171.120304   826.958761  16554              240      177
# 191     20    3  167.465510   852.877934  17487              240      192
# 208     21    3  161.964617   879.060692  18196              240      209
# 228     22    4  157.401942   905.634519  15867              240      229
# 247     23    6  155.519807   929.460291  13779              240      248
# 265     24    3  158.372719   947.105614  11313              240      266
# 283     25    2  164.748399   961.643542   9713              240      284
# 300     26    3  166.475324   983.479500   7990              240      301
# 313     27    3  168.070292  1009.824821   7570              240      314
# 327     28    2  171.646011  1037.897045   7499              240      328
# 342     29    2  175.456830  1066.948372   7989              240      343
# 355     30    2  178.192804  1097.028137   8731              240      356
# 366     31    3  182.980606  1126.186136   8812              240      367
# 375     32    4  197.966903  1162.009663   5560              240      376
# 382     33    2  197.806423  1193.867882   6148              240      383
# 391     34    2  195.757900  1229.523948   6414              240      392
# 400     35    2  193.931526  1270.791605   7563              240      401
# 407     36    3  197.744168  1296.726983   7351              240      408
# 414     37    4  205.049881  1311.707609   5672              240      415
# 420     38    2  207.176697  1325.359952   4530              240      421
# 427     39    2  203.502218  1333.572930   4549              240      428
# 435     40    1  199.131823  1338.924680   2789              240      436
# 443     41    1  200.822700  1347.437006   1992              240      444
#
#                     time              timestr   latitude  longitude   cell  \
# 0    1998-01-01 00:30:00  1998-01-01 00:30:00 -35.743217 -63.051313  19981
# 11   1998-01-01 01:30:00  1998-01-01 01:30:00 -35.678772 -62.651001  19981
# 22   1998-01-01 02:30:00  1998-01-01 02:30:00 -35.655121 -62.285432  19981
# 32   1998-01-01 03:30:00  1998-01-01 03:30:00 -35.661391 -61.724430  19981
# 42   1998-01-01 04:30:00  1998-01-01 04:30:00 -35.660202 -61.132811  19981
# 53   1998-01-01 05:30:00  1998-01-01 05:30:00 -35.593921 -60.542543  19981
# 62   1998-01-01 06:30:00  1998-01-01 06:30:00 -35.586112 -59.881338  19981
# 71   1998-01-01 07:30:00  1998-01-01 07:30:00 -35.548120 -59.104602  19981
# 80   1998-01-01 08:30:00  1998-01-01 08:30:00 -35.647722 -58.141230  19981
# 87   1998-01-01 09:30:00  1998-01-01 09:30:00 -35.800527 -57.164087  19981
# 93   1998-01-01 10:30:00  1998-01-01 10:30:00 -35.932161 -56.228684  19981
# 99   1998-01-01 11:30:00  1998-01-01 11:30:00 -35.966678 -55.407988  19981
# 107  1998-01-01 12:30:00  1998-01-01 12:30:00 -35.767882 -54.672401  19981
# 114  1998-01-01 13:30:00  1998-01-01 13:30:00 -35.376152 -53.987944  19981
# 119  1998-01-01 14:30:00  1998-01-01 14:30:00 -34.471317 -53.726701  19981
# 126  1998-01-01 15:30:00  1998-01-01 15:30:00 -33.900565 -53.832133  19981
# 135  1998-01-01 16:30:00  1998-01-01 16:30:00 -33.580436 -52.926610  19981
# 146  1998-01-01 17:30:00  1998-01-01 17:30:00 -33.294553 -52.437127  19981
# 161  1998-01-01 18:30:00  1998-01-01 18:30:00 -32.936361 -52.573950  19981
# 176  1998-01-01 19:30:00  1998-01-01 19:30:00 -33.109679 -51.548118  19981
# 191  1998-01-01 20:30:00  1998-01-01 20:30:00 -33.257697 -50.498382  19981
# 208  1998-01-01 21:30:00  1998-01-01 21:30:00 -33.480483 -49.438002  19981
# 228  1998-01-01 22:30:00  1998-01-01 22:30:00 -33.665272 -48.361755  19981
# 247  1998-01-01 23:30:00  1998-01-01 23:30:00 -33.741498 -47.396795  19981
# 265  1998-01-02 00:30:00  1998-01-02 00:30:00 -33.625957 -46.682182  19981
# 283  1998-01-02 01:30:00  1998-01-02 01:30:00 -33.367741 -46.093384  19981
# 300  1998-01-02 02:30:00  1998-01-02 02:30:00 -33.297800 -45.209036  19981
# 313  1998-01-02 03:30:00  1998-01-02 03:30:00 -33.233203 -44.142043  19981
# 327  1998-01-02 04:30:00  1998-01-02 04:30:00 -33.088388 -43.005115  19981
# 342  1998-01-02 05:30:00  1998-01-02 05:30:00 -32.934047 -41.828537  19981
# 355  1998-01-02 06:30:00  1998-01-02 06:30:00 -32.823242 -40.610311  19981
# 366  1998-01-02 07:30:00  1998-01-02 07:30:00 -32.629337 -39.429413  19981
# 375  1998-01-02 08:30:00  1998-01-02 08:30:00 -32.022390 -37.978552  19981
# 382  1998-01-02 09:30:00  1998-01-02 09:30:00 -32.028889 -36.688303  19981
# 391  1998-01-02 10:30:00  1998-01-02 10:30:00 -32.111856 -35.244224  19981
# 400  1998-01-02 11:30:00  1998-01-02 11:30:00 -32.185825 -33.572892  19981
# 407  1998-01-02 12:30:00  1998-01-02 12:30:00 -32.031411 -32.522500  19981
# 414  1998-01-02 13:30:00  1998-01-02 13:30:00 -31.735531 -31.915781  19981
# 420  1998-01-02 14:30:00  1998-01-02 14:30:00 -31.649395 -31.362864  19981
# 427  1998-01-02 15:30:00  1998-01-02 15:30:00 -31.798210 -31.030234  19981
# 435  1998-01-02 16:30:00  1998-01-02 16:30:00 -31.975212 -30.813506  19981
# 443  1998-01-02 17:30:00  1998-01-02 17:30:00 -31.906732 -30.468753  19981
#
#           time_cell            datetime  hour
# 0   0 days 00:00:00 1998-01-01 00:30:00     0
# 11  0 days 01:00:00 1998-01-01 01:30:00     1
# 22  0 days 02:00:00 1998-01-01 02:30:00     2
# 32  0 days 03:00:00 1998-01-01 03:30:00     3
# 42  0 days 04:00:00 1998-01-01 04:30:00     4
# 53  0 days 05:00:00 1998-01-01 05:30:00     5
# 62  0 days 06:00:00 1998-01-01 06:30:00     6
# 71  0 days 07:00:00 1998-01-01 07:30:00     7
# 80  0 days 08:00:00 1998-01-01 08:30:00     8
# 87  0 days 09:00:00 1998-01-01 09:30:00     9
# 93  0 days 10:00:00 1998-01-01 10:30:00    10
# 99  0 days 11:00:00 1998-01-01 11:30:00    11
# 107 0 days 12:00:00 1998-01-01 12:30:00    12
# 114 0 days 13:00:00 1998-01-01 13:30:00    13
# 119 0 days 14:00:00 1998-01-01 14:30:00    14
# 126 0 days 15:00:00 1998-01-01 15:30:00    15
# 135 0 days 16:00:00 1998-01-01 16:30:00    16
# 146 0 days 17:00:00 1998-01-01 17:30:00    17
# 161 0 days 18:00:00 1998-01-01 18:30:00    18
# 176 0 days 19:00:00 1998-01-01 19:30:00    19
# 191 0 days 20:00:00 1998-01-01 20:30:00    20
# 208 0 days 21:00:00 1998-01-01 21:30:00    21
# 228 0 days 22:00:00 1998-01-01 22:30:00    22
# 247 0 days 23:00:00 1998-01-01 23:30:00    23
# 265 1 days 00:00:00 1998-01-02 00:30:00     0
# 283 1 days 01:00:00 1998-01-02 01:30:00     1
# 300 1 days 02:00:00 1998-01-02 02:30:00     2
# 313 1 days 03:00:00 1998-01-02 03:30:00     3
# 327 1 days 04:00:00 1998-01-02 04:30:00     4
# 342 1 days 05:00:00 1998-01-02 05:30:00     5
# 355 1 days 06:00:00 1998-01-02 06:30:00     6
# 366 1 days 07:00:00 1998-01-02 07:30:00     7
# 375 1 days 08:00:00 1998-01-02 08:30:00     8
# 382 1 days 09:00:00 1998-01-02 09:30:00     9
# 391 1 days 10:00:00 1998-01-02 10:30:00    10
# 400 1 days 11:00:00 1998-01-02 11:30:00    11
# 407 1 days 12:00:00 1998-01-02 12:30:00    12
# 414 1 days 13:00:00 1998-01-02 13:30:00    13
# 420 1 days 14:00:00 1998-01-02 14:30:00    14
# 427 1 days 15:00:00 1998-01-02 15:30:00    15
# 435 1 days 16:00:00 1998-01-02 16:30:00    16
# 443 1 days 17:00:00 1998-01-02 17:30:00    17

# %%
# diff_time = (subset_CCPF.time[subset_CCPF.feature == 15661] - subset_CCPF.time[subset_CCPF.feature == 15652]).total_seconds()

# %%
#diff_time = (feature_new["time"] - feature_old["time"]).total_seconds()
#subset['time'].astype('timedelta64[ns]')

diff_time = (subset_original.time[subset_original.feature == 12] - subset_original.time[subset_original.feature == 1]).total_seconds()

# %%
import tobac

#first need to run the tobac calculate velocity function before running my own function to create the histogram
#vel_unfiltered= tobac.calculate_velocity(all_years_original, method_distance=None)
vel_filtered = tobac.calculate_velocity(all_years_CCPF, method_distance=None)

# %%
def haversine(lat1, lon1, lat2, lon2):
    """Computes the Haversine distance in kilometers.

    Calculates the Haversine distance between two points
    (based on implementation CIS https://github.com/cedadev/cis).

    Parameters
    ----------
    lat1, lon1 : array of latitude, longitude
        First point or points as array in degrees.

    lat2, lon2 : array of latitude, longitude
        Second point or points as array in degrees.

    Returns
    -------
    arclen * RADIUS_EARTH : array
        Array of Distance(s) between the two points(-arrays) in
        kilometers.

    """

    RADIUS_EARTH = 6378.0
    lat1 = np.radians(lat1)
    lat2 = np.radians(lat2)
    lon1 = np.radians(lon1)
    lon2 = np.radians(lon2)
    # print(lat1,lat2,lon1,lon2)
    arclen = 2 * np.arcsin(
        np.sqrt(
            (np.sin((lat2 - lat1) / 2)) ** 2
            + np.cos(lat1) * np.cos(lat2) * (np.sin((lon2 - lon1) / 2)) ** 2
        )
    )
    return arclen * RADIUS_EARTH


def calculate_distance(feature_1, feature_2, method_distance=None):
    """Compute the distance between two features. It is based on
    either lat/lon coordinates or x/y coordinates.

    Parameters
    ----------
    feature_1, feature_2 : pandas.DataFrame or pandas.Series
        Dataframes containing multiple features or pandas.Series
        of one feature. Need to contain either projection_x_coordinate
        and projection_y_coordinate or latitude and longitude
        coordinates.

    method_distance : {None, 'xy', 'latlon'}, optional
        Method of distance calculation. 'xy' uses the length of the
        vector between the two features, 'latlon' uses the haversine
        distance. None checks wether the required coordinates are
        present and starts with 'xy'. Default is None.

    Returns
    -------
    distance : float or pandas.Series
        Float with the distance between the two features in meters if
        the input are two pandas.Series containing one feature,
        pandas.Series of the distances if one of the inputs contains
        multiple features.

    """
    if method_distance is None:
        if (
            ("projection_x_coordinate" in feature_1)
            and ("projection_y_coordinate" in feature_1)
            and ("projection_x_coordinate" in feature_2)
            and ("projection_y_coordinate" in feature_2)
        ):
            method_distance = "xy"
        elif (
            ("latitude" in feature_1)
            and ("longitude" in feature_1)
            and ("latitude" in feature_2)
            and ("longitude" in feature_2)
        ):
            method_distance = "latlon"
        else:
            raise ValueError(
                "either latitude/longitude or projection_x_coordinate/projection_y_coordinate have to be present to calculate distances"
            )

    if method_distance == "xy":
        distance = np.sqrt(
            (
                feature_1["projection_x_coordinate"]
                - feature_2["projection_x_coordinate"]
            )
            ** 2
            + (
                feature_1["projection_y_coordinate"]
                - feature_2["projection_y_coordinate"]
            )
            ** 2
        )
    elif method_distance == "latlon":
        distance = 1000 * haversine(
            feature_1["latitude"],
            feature_1["longitude"],
            feature_2["latitude"],
            feature_2["longitude"],
        )
    else:
        raise ValueError("method undefined")
    return distance

# %%
def calculate_velocity_individual(feature_old, feature_new, method_distance=None):
    """Calculate the mean velocity of a feature between two timeframes.

    Parameters
    ----------
    feature_old : pandas.Series
        pandas.Series of a feature at a certain timeframe. Needs to
        contain a 'time' column and either projection_x_coordinate
        and projection_y_coordinate or latitude and longitude coordinates.

    feature_new : pandas.Series
        pandas.Series of the same feature at a later timeframe. Needs
        to contain a 'time' column and either projection_x_coordinate
        and projection_y_coordinate or latitude and longitude coordinates.

    method_distance : {None, 'xy', 'latlon'}, optional
        Method of distance calculation, used to calculate the velocity.
        'xy' uses the length of the vector between the two features,
        'latlon' uses the haversine distance. None checks wether the
        required coordinates are present and starts with 'xy'.
        Default is None.

    Returns
    -------
    velocity : float
        Value of the approximate velocity.

    """

    distance = calculate_distance(
        feature_old, feature_new, method_distance=method_distance
    )
    diff_time = (feature_new["time"] - feature_old["time"]).total_seconds()
    velocity = distance / diff_time
    return velocity

# %%
feature_new = subset_CCPF[subset_CCPF.feature == 15661]
feature_new['time'].dtype
feature_new

feature_old = subset_CCPF[subset_CCPF.feature == 15652]
feature_old['time'].dtype
feature_old

# %%
all_years_original.time.dtype

# %%
diff_time = (feature_new["time"] - feature_old["time"]).total_seconds()

# %%
feature_new = subset_original[subset_original.feature == 12]
feature_new['time']
#feature_new = pd.to_timedelta(feature_new.time)

feature_old = subset_original[subset_original.feature == 1]
feature_old['time'].dtype

# %%
diff_time = (feature_new["time"] - feature_old["time"]).total_seconds()

# %%
velocity = calculate_velocity_individual(subset_original[subset_original.feature == 12], subset_original[subset_original.feature == 1], method_distance=None)

# %%
vel_unfiltered= tobac.calculate_velocity(all_years_original, method_distance=None)

# %%
all_years_CCPF

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import mpl_toolkits
from mpl_toolkits.basemap import Basemap

x_f = all_years_CCPF.longitude
y_f = all_years_CCPF.latitude

x_o = all_years_original.longitude
y_o = all_years_original.latitude


fig = plt.figure(figsize=(22,12))

ax1=plt.subplot(1,3,1)
m = Basemap(llcrnrlon=-80, llcrnrlat=-38,urcrnrlon=-30, urcrnrlat=10) # create Basemap object
m.drawcoastlines() # draw coastlines
#m.drawcountries() # draw political boundaries
m.shadedrelief()

hx_o = m.hexbin(x_o, y_o, gridsize=(8,8),cmap='Reds',alpha=0.6, vmin=0,vmax=1000, extent=(-80, -30, -40, 15))
cbar = plt.colorbar(hx_o, ax=ax1, shrink=0.4, label='Hours with MCS present', extend='max')
ax1.set_xlabel('Lon $^\circ$E', fontsize=15)
ax1.set_ylabel('Lat $^\circ$N', fontsize=15)
ax1.set_title('MCS frequency in {} (original)'.format(year), fontsize=20)


ax2=plt.subplot(1,3,2)
m = Basemap(llcrnrlon=-80, llcrnrlat=-38,urcrnrlon=-30, urcrnrlat=10) # create Basemap object
m.drawcoastlines() # draw coastlines
#m.drawcountries() # draw political boundaries
m.shadedrelief()

hx_f = m.hexbin(x_f, y_f, gridsize=(8,8),cmap='Reds',alpha=0.6, vmin=0,vmax=1000, extent=(-80, -30, -40, 15))
cbar = plt.colorbar(hx_f, ax=ax2, shrink=0.4, label='Hours with MCS present', extend='max')
ax2.set_xlabel('Lon $^\circ$E', fontsize=15)
ax2.set_ylabel('Lat $^\circ$N', fontsize=15)
ax2.set_title('MCS frequency in {} (filtered)'.format(year), fontsize=20)


ax3=plt.subplot(1,3,3)
m = Basemap(llcrnrlon=-80, llcrnrlat=-38,urcrnrlon=-30, urcrnrlat=10) # create Basemap object
m.drawcoastlines() # draw coastlines
#m.drawcountries() # draw political boundaries
m.shadedrelief()

# Create dummy hexbin using whatever data..:
hx_diff=m.hexbin(x_f, y_f, gridsize=(8,8), cmap='RdBu_r',alpha=0.6, vmin=-500,vmax=500, extent=(-80, -30, -40, 15))
hx_diff.set_array(hx_f.get_array()-hx_o.get_array())
cbar = plt.colorbar(hx_diff, ax=ax3, shrink=0.4, extend='both')
cbar.set_label(label='filtered - original')
#cbar.ax.tick_params(labelsize=12)
ax3.set_xlabel('Lon $^\circ$E', fontsize=15)
ax3.set_ylabel('Lat $^\circ$N', fontsize=15)
ax3.set_title('Difference', fontsize=20)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /data/users/hgilmour/cold-core-filtering/filtered_v_unfiltered_analysis.ipynb Cell 70 line 7
#       <a href='vscode-notebook-cell:/data/users/hgilmour/cold-core-filtering/filtered_v_unfiltered_analysis.ipynb#Y126sZmlsZQ%3D%3D?line=3'>4</a> import mpl_toolkits
#       <a href='vscode-notebook-cell:/data/users/hgilmour/cold-core-filtering/filtered_v_unfiltered_analysis.ipynb#Y126sZmlsZQ%3D%3D?line=4'>5</a> from mpl_toolkits.basemap import Basemap
# ----> <a href='vscode-notebook-cell:/data/users/hgilmour/cold-core-filtering/filtered_v_unfiltered_analysis.ipynb#Y126sZmlsZQ%3D%3D?line=6'>7</a> x_f = all_years_CCPF.longitude
#       <a href='vscode-notebook-cell:/data/users/hgilmour/cold-core-filtering/filtered_v_unfiltered_analysis.ipynb#Y126sZmlsZQ%3D%3D?line=7'>8</a> y_f = all_years_CCPF.latitude
#      <a href='vscode-notebook-cell:/data/users/hgilmour/cold-core-filtering/filtered_v_unfiltered_analysis.ipynb#Y126sZmlsZQ%3D%3D?line=9'>10</a> x_o = all_years_original.longitude
#
# File ~/.conda/envs/myclone/lib/python3.9/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'longitude'
