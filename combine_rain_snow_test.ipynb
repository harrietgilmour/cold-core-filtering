# %%
import xarray as xr
import iris
import numpy as np

# %%
precip_file = '/scratch/hgilmour/cpm_PD/precip/1998/precip_merge_05_1998.nc'
precip = xr.open_dataset(precip_file)
precip = precip.stratiform_rainfall_flux

# %%
precip
# Out:
# <xarray.DataArray 'stratiform_rainfall_flux' (time: 720, latitude: 1360,
#                                               longitude: 1360)>
# [1331712000 values with dtype=float32]
# Coordinates:
#   * time                     (time) object 1998-05-01 00:30:00 ... 1998-05-30...
#   * latitude                 (latitude) float32 -40.04 -40.0 ... 14.96 15.0
#   * longitude                (longitude) float32 275.0 275.0 ... 330.0 330.0
#     forecast_period          (time) timedelta64[ns] ...
#     forecast_reference_time  object ...
# Attributes:
#     standard_name:    stratiform_rainfall_flux
#     units:            kg m-2 s-1
#     um_stash_source:  m01s04i203
#     cell_methods:     time: mean (interval: 1 hour)
#     grid_mapping:     latitude_longitude

# %%
snow_file = '/scratch/hgilmour/cpm_PD/snow/1998/snow_merge_05_1998.nc'
snow = xr.open_dataset(snow_file)
snow = snow.stratiform_snowfall_flux

# %%
snow
# Out:
# <xarray.DataArray 'stratiform_snowfall_flux' (time: 720, latitude: 1360,
#                                               longitude: 1360)>
# [1331712000 values with dtype=float32]
# Coordinates:
#   * time                     (time) object 1998-05-01 00:30:00 ... 1998-05-30...
#   * latitude                 (latitude) float32 -40.04 -40.0 ... 14.96 15.0
#   * longitude                (longitude) float32 275.0 275.0 ... 330.0 330.0
#     forecast_period          (time) timedelta64[ns] ...
#     forecast_reference_time  object ...
# Attributes:
#     standard_name:    stratiform_snowfall_flux
#     units:            kg m-2 s-1
#     um_stash_source:  m01s04i204
#     cell_methods:     time: mean (interval: 1 hour)
#     grid_mapping:     latitude_longitude

# %%
precip[0,:,:]
# Out:
# <xarray.DataArray 'stratiform_rainfall_flux' (latitude: 1360, longitude: 1360)>
# [1849600 values with dtype=float32]
# Coordinates:
#     time                     object 1998-05-01 00:30:00
#   * latitude                 (latitude) float32 -40.04 -40.0 ... 14.96 15.0
#   * longitude                (longitude) float32 275.0 275.0 ... 330.0 330.0
#     forecast_period          timedelta64[ns] ...
#     forecast_reference_time  object ...
# Attributes:
#     standard_name:    stratiform_rainfall_flux
#     units:            kg m-2 s-1
#     um_stash_source:  m01s04i203
#     cell_methods:     time: mean (interval: 1 hour)
#     grid_mapping:     latitude_longitude

# %%
total_precip_file = '/scratch/hgilmour/cpm_PD/total_precip/annual_files/total_precip_1998.nc'
total_precip = xr.open_dataset(total_precip_file)
total_precip = total_precip.__xarray_dataarray_variable__

# %%
total_precip
# Out:
# <xarray.DataArray '__xarray_dataarray_variable__' (time: 8640, latitude: 1360,
#                                                    longitude: 1360)>
# [15980544000 values with dtype=float32]
# Coordinates:
#   * time       (time) object 1998-01-01 00:30:00 ... 1998-12-30 23:30:00
#   * longitude  (longitude) float32 275.0 275.0 275.0 275.1 ... 329.9 330.0 330.0
#   * latitude   (latitude) float32 -40.04 -40.0 -39.96 ... 14.92 14.96 15.0

# %%
total_precip[2880,:,:]
# Out:
# <xarray.DataArray '__xarray_dataarray_variable__' (latitude: 1360,
#                                                    longitude: 1360)>
# [1849600 values with dtype=float32]
# Coordinates:
#     time       object 1998-05-01 00:30:00
#   * longitude  (longitude) float32 275.0 275.0 275.0 275.1 ... 329.9 330.0 330.0
#   * latitude   (latitude) float32 -40.04 -40.0 -39.96 ... 14.92 14.96 15.0

# %%
difference = total_precip[2880,:,:]-precip[0,:,:]

# %%
difference.plot(cmap='rainbow')

# %%
snow[0,:,:].plot(cmap='rainbow')
