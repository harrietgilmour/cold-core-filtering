# %%
import glob
import pandas as pd

precip = pd.DataFrame()

for file in glob.iglob('/data/users/hgilmour/cold-core-filtering/Save/CC&PF/*.hdf'):   
   file = pd.read_hdf(file, 'table')
   precip = pd.concat([precip, file])

print(precip)
# Out:
#       frame  idx      hdim_1      hdim_2   num  threshold_value  feature  \
# 5094    404  192  895.129704  990.750856  2921              240     5095
# 5104    405  154  896.933437  987.794479  3452              240     5105
# 5119    406  159  904.169606  982.666063  4211              240     5120
# 5133    407  146  912.330189  976.992186  5436              240     5134
# 5145    408  126  917.242474  970.265297  6523              240     5146
# ...     ...  ...         ...         ...   ...              ...      ...
# 1713    121  142  787.815426  884.824504  3301              240     1714
# 1727    122  114  789.523351  882.852131  3856              240     1728
# 1741    123  118  790.395635  879.315758  3707              240     1742
# 1753    124  104  793.223009  873.981790  3357              240     1754
# 1764    125  131  800.116547  868.606793  2106              240     1765
#
#                      time              timestr  latitude  ...  \
# ...

# %%
precip
# Out:
#       frame  idx      hdim_1      hdim_2   num  threshold_value  feature  \
# 5094    404  192  895.129704  990.750856  2921              240     5095
# 5104    405  154  896.933437  987.794479  3452              240     5105
# 5119    406  159  904.169606  982.666063  4211              240     5120
# 5133    407  146  912.330189  976.992186  5436              240     5134
# 5145    408  126  917.242474  970.265297  6523              240     5146
# ...     ...  ...         ...         ...   ...              ...      ...
# 1713    121  142  787.815426  884.824504  3301              240     1714
# 1727    122  114  789.523351  882.852131  3856              240     1728
# 1741    123  118  790.395635  879.315758  3707              240     1742
# 1753    124  104  793.223009  873.981790  3357              240     1754
# 1764    125  131  800.116547  868.606793  2106              240     1765
#
#                      time              timestr  latitude  ...  \
# ...

# %%
no_precip = pd.DataFrame()

for file in glob.iglob('/data/users/hgilmour/cold-core-filtering/Save/deleted_tracks/precip/*.hdf'):   
   file = pd.read_hdf(file, 'table')
   no_precip = pd.concat([no_precip, file])

# %%
no_precip
# Out:
#       frame  idx      hdim_1       hdim_2   num  threshold_value  feature  \
# 1238     81    1   65.714917   876.556723  5743              240     1239
# 1253     82    1   60.343530   876.269496  4927              240     1254
# 1270     83    1   35.530398   916.905883  3951              240     1271
# 1287     84    1   35.436530   923.182965  4159              240     1288
# 1300     85    1   27.839749   938.782780  2887              240     1301
# ...     ...  ...         ...          ...   ...              ...      ...
# 2751    210  105  572.162789  1309.761008  4208              240     2752
# 2767    211  109  574.787497  1311.178707  3794              240     2768
# 2782    212  121  572.149582  1313.303895  3548              240     2783
# 2797    213   91  568.374333  1319.225813  2737              240     2798
# 2815    214   93  565.936026  1323.672375  2066              240     2816
#
#                      time              timestr   latitude  ...  \
# ...

# %%
no_CC = pd.DataFrame()

for file in glob.iglob('/data/users/hgilmour/cold-core-filtering/Save/deleted_tracks/cold_core/*.hdf'):   
   file = pd.read_hdf(file, 'table')
   no_CC = pd.concat([no_CC, file])

# %%
no_CC
# Out:
#       frame  idx      hdim_1       hdim_2    num  threshold_value  feature  \
# 736      49    5   82.556428   479.347821   3031              240      737
# 749      50    5   83.329435   492.158048   4284              240      750
# 766      51    4   80.080243   506.785626   5732              240      767
# 781      52    3   71.752126   522.425821   5775              240      782
# 794      53    1   52.887373   557.028823   7127              240      795
# ...     ...  ...         ...          ...    ...              ...      ...
# 2732    209   10  173.576402  1234.468203  11244              240     2733
# 2747    210   11  182.114961  1242.403380  11464              240     2748
# 2762    211   12  181.840307  1239.966435   9799              240     2763
# 2777    212   14  174.941721  1235.195366   5119              240     2778
# 2792    213   15  186.834555  1252.887189   3941              240     2793
#
#                      time              timestr   latitude  ...  \
# ...

# %%
file = '/data/users/hgilmour/tracking/code/tobac_sensitivity/Save/tracks_2005_01.h5'

original = pd.read_hdf(file, 'table')

# %%
original
# Out:
#       frame  idx       hdim_1       hdim_2    num  threshold_value  feature  \
# 0         0    9   179.648443   518.713643   3617              240        1
# 1         0   26   319.360864   876.726404   7359              240        2
# 2         0   57   465.549812  1014.466367   5384              240        3
# 3         0   73   763.319602   705.760312  47759              240        4
# 4         0   86   577.470368   717.240701   2132              240        5
# ...     ...  ...          ...          ...    ...              ...      ...
# 9076    743  241   882.032521   698.342702   7910              240     9077
# 9077    743  252   940.225439   833.293263   3228              240     9078
# 9078    743  272  1046.778633  1275.959222  20583              240     9079
# 9079    743  320  1097.697734   916.296729   3373              240     9080
# 9080    743  328  1142.170021  1089.531691  14727              240     9081
#
# ...

# %%
original = original[original.cell >= 0]

# %%
import numpy as np

# %%
print(np.unique(precip.cell.values).shape[0])

print(np.unique(no_precip.cell.values).shape[0])

print(np.unique(no_CC.cell.values).shape[0])

print(np.unique(original.cell.values).shape[0])
# Out:
# 372
# 17
# 38
# 391
